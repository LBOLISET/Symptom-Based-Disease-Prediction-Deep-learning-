# %%
# !sudo apt-get install espeak
# Out:
# Password:
# sudo: a password is required

# %%
# !pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (2.98)
# Requirement already satisfied: pyobjc>=2.4 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-core==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-libdispatch==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-libxpc==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Accessibility==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AdServices==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AdSupport==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AVKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AVFoundation==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AVRouting==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Accounts==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AddressBook==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Automator==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-BrowserEngineKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-BusinessChat==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CFNetwork==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CalendarStore==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CallKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Cinematic==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ClassKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CloudKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Cocoa==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Collaboration==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ColorSync==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Contacts==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ContactsUI==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreAudio==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreData==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreLocation==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreMedia==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreML==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreMotion==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreServices==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreText==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-DataDetection==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-DiscRecording==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-EventKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-FileProvider==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-FSEvents==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-FinderSync==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-GameCenter==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-GameController==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-HealthKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Intents==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-IntentsUI==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-InstantMessage==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-IOSurface==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-KernelManagement==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-LaunchServices==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MailKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MapKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Metal==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MetalFX==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MetalKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MetricKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MLCompute==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ModelIO==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-NetFS==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Network==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-OSAKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-OSLog==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-PassKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-PencilKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-PHASE==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Photos==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-PhotosUI==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-PushKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Quartz==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ReplayKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SafetyKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SafariServices==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ScreenTime==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Security==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SearchKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ShazamKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Social==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Speech==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SpriteKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-StoreKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SyncServices==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-WebKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-GameKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-GameplayKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SceneKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SensitiveContentAnalysis==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Symbols==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-UserNotifications==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Virtualization==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-Vision==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==10.3.2 in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.2)

# %%
pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages (0.18.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import re
from datetime import datetime
from collections import deque
import time
import os
from fuzzywuzzy import process

class MedicalDiagnosisSystem:
    def __init__(self):
        self.model = None
        self.tokenizer = None
        self.label_encoder = None
        self.max_length = 3
        self.max_words = 1000

    def initialize_system(self):
        """Initialize the medical diagnosis system"""
        print("\n🔄 Initializing Medical Diagnosis System...")
        try:
            # Load datasets
            dataset = pd.read_csv('dataset.csv')
            self.load_supplementary_data()

            # Prepare data
            symptom_cols = dataset.columns[1:]
            X = dataset[symptom_cols].fillna('').agg(' '.join, axis=1)
            y = dataset['Disease']

            # Encode labels
            self.label_encoder = LabelEncoder()
            y = self.label_encoder.fit_transform(y)

            # Prepare text data
            self.tokenizer = Tokenizer(num_words=self.max_words, oov_token="<OOV>")
            self.tokenizer.fit_on_texts(X)

            # Train model
            self.train_model(X, y)

            print("✅ System initialization complete!")
            return True

        except Exception as e:
            print(f"❌ Error during initialization: {str(e)}")
            return False

    def load_supplementary_data(self):
        """Load additional medical data"""
        self.symptom_precautions = pd.read_csv('symptom_precaution.csv')
        self.symptom_severity = pd.read_csv('Symptom-severity.csv')
        self.symptom_description = pd.read_csv('symptom_Description.csv')

    def train_model(self, X, y):
        """Train the neural network model"""
        # Convert text to sequences
        X_seq = self.tokenizer.texts_to_sequences(X)
        X_pad = pad_sequences(X_seq, maxlen=self.max_length)

        # Split data
        X_train, X_test, y_train, y_test = train_test_split(
            X_pad, y, test_size=0.2, random_state=42
        )

        # Build model
        self.model = tf.keras.Sequential([
            tf.keras.layers.Embedding(self.max_words, 100, input_length=self.max_length),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(len(np.unique(y)), activation='softmax')
        ])

        # Compile and train
        self.model.compile(optimizer='adam',
                          loss='sparse_categorical_crossentropy',
                          metrics=['accuracy'])

        self.model.fit(X_train, y_train, epochs=10, validation_split=0.2, verbose=1)

class InteractiveMedicalChatbot:
    def __init__(self, diagnosis_system):
        self.diagnosis_system = diagnosis_system
        self.conversation_history = deque(maxlen=10)
        self.current_symptoms = []
        self.last_prediction = None
        self.user_name = None
        self.available_symptoms = self.load_available_symptoms()

    def load_available_symptoms(self):
        """Load and return list of available symptoms from the dataset"""
        if hasattr(self.diagnosis_system, 'symptom_severity'):
            return self.diagnosis_system.symptom_severity['Symptom'].unique().tolist()
        return []

    def display_welcome_message(self):
        """Display welcome message and instructions"""
        os.system('cls' if os.name == 'nt' else 'clear')
        print("\n" + "="*60)
        print("🏥 Welcome to the Interactive Medical Symptom Analysis System!")
        print("="*60)

        self.user_name = input("\nPlease enter your name: ")
        print(f"\nHello {self.user_name}! 👋 I'm your medical assistant chatbot.")
        print("\nBefore we begin, please note:")
        print("1️⃣ This system is for educational purposes only")
        print("2️⃣ Always consult healthcare professionals for medical advice")
        print("3️⃣ In case of emergency, call emergency services immediately")

        input("\nPress Enter to continue...")

    def display_instructions(self):
        """Display detailed instructions"""
        print("\n📋 How to Use This System:")
        print("1. You can either describe your symptoms or choose from our list")
        print("2. The system will analyze your symptoms and suggest possible conditions")
        print("3. Follow-up questions will help refine the diagnosis")
        print("4. You can view detailed information about conditions")
        print("\n⚠️ Important: If you experience severe symptoms, seek immediate")
        print("   medical attention or call emergency services.")

        input("\nPress Enter to continue to the main menu...")

    def show_menu(self):
        """Display main menu options"""
        print("\n" + "="*40)
        print(f"🏥 Medical Assistant - {self.user_name}'s Session")
        print("="*40)
        print("\n📋 Menu Options:")
        print("1. Describe your symptoms")
        print("2. Browse symptom catalog")
        print("3. View your current symptoms")
        print("4. Emergency information")
        print("5. Help & Instructions")
        print("6. Exit")

        return input("\n👉 Please select an option (1-6): ")

    def process_symptoms(self):
        """Handle symptom input and processing"""
        print("\n🔍 Symptom Analysis")
        symptoms = []
        print("\nEnter your symptoms one by one (type 'done' when finished):")
        print("Tip: You can type part of the symptom name and we'll help you find it")
    
        while True:
            symptom_input = input("Enter symptom (or 'done' to finish): ").strip().lower()
        
            if symptom_input == 'done':
                if not symptoms:
                    print("Warning: No symptoms were entered. Are you sure you want to finish? (yes/no)")
                    if input().lower().startswith('y'):
                        break
                else:
                    print(f"\nFinal list of symptoms:")
                    for i, sym in enumerate(symptoms, 1):
                        print(f"{i}. {sym.replace('_', ' ')}")
                    break
        
            elif not symptom_input:
                print("Please enter a symptom or type 'done' to finish")
                continue
        
            symptoms.append(symptom_input)
    
        # Match entered symptoms with available symptoms using fuzzy matching
        matched_symptoms = self.match_symptoms(symptoms)
        if matched_symptoms:
            print("\n✅ Symptoms matched successfully:")
            for symptom in matched_symptoms:
                print(f"  • {symptom}")
        else:
            print("\n⚠️ No exact matches found, trying closest matches...")

        # Process symptoms and get prediction
        predictions = self.get_diagnosis(" ".join(matched_symptoms))
        self.display_diagnosis(predictions)

    def match_symptoms(self, symptoms):
        """Match user input symptoms with available symptoms using fuzzy matching"""
        symptoms_list = self.available_symptoms
        matched_symptoms = []

        for symptom in symptoms:
            # Find the closest match from the available symptoms
            closest_match = process.extractOne(symptom, symptoms_list)
            if closest_match and closest_match[1] > 70:  # If match score is above 70%
                matched_symptoms.append(closest_match[0])
            else:
                print(f"⚠️ No close match found for: {symptom}")
        return matched_symptoms

    def get_diagnosis(self, symptoms):
        """Get diagnosis based on symptoms"""
        # Clean symptoms text
        cleaned_symptoms = re.sub(r'[^a-zA-Z\s,]', '', symptoms)
        symptoms_seq = self.diagnosis_system.tokenizer.texts_to_sequences([cleaned_symptoms])
        symptoms_pad = pad_sequences(symptoms_seq,
                                   maxlen=self.diagnosis_system.max_length,
                                   padding='post')

        # Get prediction
        prediction = self.diagnosis_system.model.predict(symptoms_pad, verbose=0)

        # Get top 3 predictions
        top_indices = np.argsort(prediction[0])[-3:][::-1]
        results = []

        for idx in top_indices:
            disease = self.diagnosis_system.label_encoder.inverse_transform([idx])[0]
            confidence = prediction[0][idx]
            if confidence > 0.1:  # Minimum confidence threshold
                results.append((disease, confidence))

        return results

    def display_diagnosis(self, predictions):
        """Display diagnosis results"""
        if not predictions:
            print("\n⚠️ Unable to make a confident diagnosis based on provided symptoms.")
            print("Please provide more specific symptoms or consult a healthcare provider.")
            return

        print("\n📋 Diagnosis Results:")
        print("="*40)

        for disease, confidence in predictions:
            print(f"\n🔍 Possible Condition: {disease}")
            print(f"📊 Confidence Level: {confidence:.1%}")

            # Get disease information
            description = self.get_disease_description(disease)
            precautions = self.get_disease_precautions(disease)

            print("\n📝 Description:")
            print(description)

            if precautions:
                print("\n⚠️ Recommended Precautions:")
                for i, precaution in enumerate(precautions, 1):
                    print(f"{i}. {precaution}")

    def display_all_symptoms(self):
        """Display all available symptoms with severity levels"""
        if not self.available_symptoms:
            print("\n⚠️ No symptoms available in the database.")
            return

        print("\n📋 Available Symptoms:")
        print("="*50)

        # Group symptoms by severity if available
        if hasattr(self.diagnosis_system, 'symptom_severity'):
            severity_df = self.diagnosis_system.symptom_severity
            for severity in sorted(severity_df['weight'].unique(), reverse=True):
                symptoms = severity_df[severity_df['weight'] == severity]['Symptom'].tolist()
                print(f"\n🔵 Severity Level {severity}:")
                for symptom in sorted(symptoms):
                    print(f"  • {symptom}")
        else:
            # Simple alphabetical list if no severity data
            for symptom in sorted(self.available_symptoms):
                print(f"• {symptom}")

        input("\nPress Enter to continue...")

    def search_symptoms(self):
        """Search through available symptoms"""
        search_term = input("\nEnter search term: ").lower()

        if len(search_term) < 2:
            print("⚠️ Please enter at least 2 characters.")
            return

        matches = [s for s in self.available_symptoms
                  if search_term in s.lower()]

        if not matches:
            print("\n❌ No matching symptoms found.")
            return

        print("\n🔍 Matching Symptoms:")
        for i, symptom in enumerate(matches, 1):
            print(f"{i}. {symptom}")

        # Option to add symptoms to current list
        choice = input("\nEnter number to add symptom (or press Enter to skip): ")
        if choice.isdigit() and 0 < int(choice) <= len(matches):
            self.current_symptoms.append(matches[int(choice)-1])
            print(f"\n✅ Added '{matches[int(choice)-1]}' to your symptoms.")

    def view_symptoms_by_category(self):
        """Display symptoms grouped by body system/category"""
        # Define basic categories and their keywords
        categories = {
            "Head & Neurological": ["head", "brain", "neural", "mental"],
            "Respiratory": ["breath", "lung", "chest", "cough"],
            "Digestive": ["stomach", "digest", "bowel", "nausea"],
            "Musculoskeletal": ["muscle", "joint", "bone", "pain"],
            "Skin": ["skin", "rash", "itch"],
            "General": []  # For symptoms that don't match other categories
        }

        # Categorize symptoms
        categorized_symptoms = {cat: [] for cat in categories}

        for symptom in self.available_symptoms:
            categorized = False
            for cat, keywords in categories.items():
                if any(keyword in symptom.lower() for keyword in keywords):
                    categorized_symptoms[cat].append(symptom)
                    categorized = True
                    break
            if not categorized:
                categorized_symptoms["General"].append(symptom)

        # Display categorized symptoms
        print("\n📋 Symptoms by Category:")
        for category, symptoms in categorized_symptoms.items():
            if symptoms:
                print(f"\n🔵 {category}:")
                for symptom in sorted(symptoms):
                    print(f"  • {symptom}")

        input("\nPress Enter to continue...")

    def view_current_symptoms(self):
        """Display currently recorded symptoms"""
        if not self.current_symptoms:
            print("\n📋 No symptoms currently recorded.")
            return

        print("\n📋 Your Current Symptoms:")
        for i, symptom in enumerate(self.current_symptoms, 1):
            print(f"{i}. {symptom}")

        # Option to remove symptoms
        choice = input("\nEnter number to remove symptom (or press Enter to continue): ")
        if choice.isdigit() and 0 < int(choice) <= len(self.current_symptoms):
            removed = self.current_symptoms.pop(int(choice)-1)
            print(f"\n✅ Removed '{removed}' from your symptoms.")

    def get_disease_description(self, disease):
        """Get description for a specific disease"""
        if hasattr(self.diagnosis_system, 'symptom_description'):
            description_df = self.diagnosis_system.symptom_description
            if disease in description_df['Disease'].values:
                return description_df[description_df['Disease'] == disease]['Description'].iloc[0]
        return "Description not available."

    def get_disease_precautions(self, disease):
        """Get precautions for a specific disease"""
        if hasattr(self.diagnosis_system, 'symptom_precautions'):
            precautions_df = self.diagnosis_system.symptom_precautions
            if disease in precautions_df['Disease'].values:
                precautions = precautions_df[precautions_df['Disease'] == disease]
                return [p for p in precautions.iloc[0, 1:] if isinstance(p, str)]
        return []

    def show_emergency_info(self):
        """Display emergency information and contacts"""
        print("\n🚨 EMERGENCY INFORMATION 🚨")
        print("="*50)
        print("\nIf you experience any of these symptoms:")
        print("• Difficulty breathing or shortness of breath")
        print("• Chest pain or pressure")
        print("• Sudden severe pain")
        print("• Sudden confusion or inability to speak")
        print("• Severe allergic reaction")

        print("\n⚠️ IMMEDIATELY:")
        print("1. Call your local emergency number:")
        print("   • United States: 911")
        print("   • Europe: 112")
        print("   • UK: 999")
        print("2. Do not wait - every minute counts!")
        print("3. If possible, have someone stay with you")

        input("\nPress Enter to return to main menu...")

    def browse_symptoms(self):
        """Browse and select from available symptoms"""
        while True:
            print("\n📋 Symptom Catalog:")
            print("1. View all symptoms")
            print("2. Search symptoms")
            print("3. View by category")
            print("4. Return to main menu")

            choice = input("\nSelect an option (1-4): ")

            if choice == "1":
                self.display_all_symptoms()
            elif choice == "2":
                self.search_symptoms
                self.search_symptoms()
            elif choice == "3":
                self.view_symptoms_by_category()
            elif choice == "4":
                break

    def run(self):
        """Main chatbot loop"""
        self.display_welcome_message()
        self.display_instructions()

        while True:
            choice = self.show_menu()

            if choice == "1":
                self.process_symptoms()
            elif choice == "2":
                self.browse_symptoms()
            elif choice == "3":
                self.view_current_symptoms()
            elif choice == "4":
                
                self.show_emergency_info()
            elif choice == "5":
                self.display_instructions()
            elif choice == "6":
                self.display_goodbye_message()
                break
            else:
                print("\n⚠️ Invalid option. Please try again.")

    def display_goodbye_message(self):
        """Display goodbye message"""
        print("\n" + "="*60)
        print(f"👋 Thank you for using our service, {self.user_name}!")
        print("Take care and remember to consult healthcare professionals")
        print("for proper medical advice and treatment.")
        print("="*60)

# Main execution
def main():
    try:
        # Initialize the medical diagnosis system
        print("\n🏥 Starting Medical Diagnosis System...")
        diagnosis_system = MedicalDiagnosisSystem()

        if not diagnosis_system.initialize_system():
            print("❌ System initialization failed. Please check your data files.")
            return

        # Create and run the chatbot
        chatbot = InteractiveMedicalChatbot(diagnosis_system)
        chatbot.run()

    except Exception as e:
        print(f"\n❌ An error occurred: {str(e)}")
        print("Please ensure all required files are present and try again.")

if __name__ == "__main__":
    main()
# Out:
# 🏥 Starting Medical Diagnosis System...
#
# 🔄 Initializing Medical Diagnosis System...
# Epoch 1/10
# /Users/lakshmimounikab/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3946 - loss: 3.2608 - val_accuracy: 0.9112 - val_loss: 0.4035
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8882 - loss: 0.4471 - val_accuracy: 0.9162 - val_loss: 0.1553
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9100 - loss: 0.2223 - val_accuracy: 0.9201 - val_loss: 0.1350
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9176 - loss: 0.1817 - val_accuracy: 0.9226 - val_loss: 0.1277
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9159 - loss: 0.1660 - val_accuracy: 0.9277 - val_loss: 0.1218
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9165 - loss: 0.1526 - val_accuracy: 0.9264 - val_loss: 0.1216
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9255 - loss: 0.1616 - val_accuracy: 0.9201 - val_loss: 0.1223
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9292 - loss: 0.1320 - val_accuracy: 0.9277 - val_loss: 0.1258
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9208 - loss: 0.1512 - val_accuracy: 0.9251 - val_loss: 0.1206
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9114 - loss: 0.1459 - val_accuracy: 0.9277 - val_loss: 0.1205
# ✅ System initialization complete!
#
# ============================================================
# 🏥 Welcome to the Interactive Medical Symptom Analysis System!
# ============================================================
#
# Hello laasya! 👋 I'm your medical assistant chatbot.
#
# Before we begin, please note:
# 1️⃣ This system is for educational purposes only
# 2️⃣ Always consult healthcare professionals for medical advice
# 3️⃣ In case of emergency, call emergency services immediately
#
# 📋 How to Use This System:
# 1. You can either describe your symptoms or choose from our list
# 2. The system will analyze your symptoms and suggest possible conditions
# 3. Follow-up questions will help refine the diagnosis
# 4. You can view detailed information about conditions
#
# ⚠️ Important: If you experience severe symptoms, seek immediate
#    medical attention or call emergency services.
#
# ========================================
# 🏥 Medical Assistant - laasya's Session
# ========================================
#
# 📋 Menu Options:
# 1. Describe your symptoms
# 2. Browse symptom catalog
# 3. View your current symptoms
# 4. Emergency information
# 5. Help & Instructions
# 6. Exit
#
# 🔍 Symptom Analysis
#
# Enter your symptoms one by one (type 'done' when finished):
# Tip: You can type part of the symptom name and we'll help you find it
#
# Final list of symptoms:
# 1. vomiting
# 2. headache
# 3. bodypain
# ⚠️ No close match found for: bodypain
#
# ✅ Symptoms matched successfully:
#   • vomiting
#   • headache
#
# 📋 Diagnosis Results:
# ========================================
#
# 🔍 Possible Condition: GERD
# 📊 Confidence Level: 32.6%
#
# 📝 Description:
# Gastroesophageal reflux disease, or GERD, is a digestive disorder that affects the lower esophageal sphincter (LES), the ring of muscle between the esophagus and stomach. Many people, including pregnant women, suffer from heartburn or acid indigestion caused by GERD.
#
# ⚠️ Recommended Precautions:
# 1. avoid fatty spicy food
# 2. avoid lying down after eating
# 3. maintain healthy weight
# 4. exercise
#
# ========================================
# 🏥 Medical Assistant - laasya's Session
# ========================================
#
# 📋 Menu Options:
# 1. Describe your symptoms
# 2. Browse symptom catalog
# 3. View your current symptoms
# 4. Emergency information
# 5. Help & Instructions
# 6. Exit
#
# 🔍 Symptom Analysis
#
# Enter your symptoms one by one (type 'done' when finished):
# Tip: You can type part of the symptom name and we'll help you find it
#
# Final list of symptoms:
# 1. cramps
# 2. yellow skin
#
# ✅ Symptoms matched successfully:
#   • cramps
#   • yellowish_skin
#
# ⚠️ Unable to make a confident diagnosis based on provided symptoms.
# Please provide more specific symptoms or consult a healthcare provider.
#
# ========================================
# 🏥 Medical Assistant - laasya's Session
# ========================================
#
# 📋 Menu Options:
# 1. Describe your symptoms
# 2. Browse symptom catalog
# 3. View your current symptoms
# 4. Emergency information
# 5. Help & Instructions
# 6. Exit
#
# 📋 Symptom Catalog:
# 1. View all symptoms
# 2. Search symptoms
# 3. View by category
# 4. Return to main menu
#
# 📋 Available Symptoms:
# ==================================================
#
# 🔵 Severity Level 7:
#   • chest_pain
#   • coma
#   • high_fever
#   • swelling_of_stomach
#   • weakness_in_limbs
#
# 🔵 Severity Level 6:
#   • abnormal_menstruation
#   • acute_liver_failure
#   • burning_micturition
#   • continuous_feel_of_urine
#   • diarrhoea
#   • dischromic_patches
#   • enlarged_thyroid
#   • fluid_overload
#   • irritation_in_anus
#   • malaise
#   • pain_in_anal_region
#   • patches_in_throat
#   • prominent_veins_on_calf
#   • spinning_movements
#   • spotting_urination
#   • stomach_bleeding
#   • swelled_lymph_nodes
#
# 🔵 Severity Level 5:
#   • blood_in_sputum
#   • bloody_stool
#   • blurred_and_distorted_vision
#   • brittle_nails
#   • cold_hands_and_feets
#   • congestion
#   • extra_marital_contacts
#   • family_history
#   • fast_heart_rate
#   • foul_smell_ofurine
#   • history_of_alcohol_consumption
#   • increased_appetite
#   • indigestion
#   • irregular_sugar_level
#   • mild_fever
#   • movement_stiffness
#   • nausea
#   • neck_pain
#   • pain_during_bowel_movements
#   • passage_of_gases
#   • phlegm
#   • prognosis
#   • puffy_face_and_eyes
#   • receiving_blood_transfusion
#   • redness_of_eyes
#   • restlessness
#   • runny_nose
#   • shivering
#   • stomach_pain
#   • swelling_joints
#   • swollen_blood_vessels
#   • swollen_extremeties
#   • swollen_legs
#   • toxic_look_(typhos)
#   • vomiting
#
# 🔵 Severity Level 4:
#   • abdominal_pain
#   • anxiety
#   • belly_pain
#   • bladder_discomfort
#   • blister
#   • breathlessness
#   • bruising
#   • constipation
#   • continuous_sneezing
#   • cough
#   • cramps
#   • dark_urine
#   • dehydration
#   • distention_of_abdomen
#   • dizziness
#   • drying_and_tingling_lips
#   • excessive_hunger
#   • fatigue
#   • fluid_overload
#   • internal_itching
#   • loss_of_appetite
#   • loss_of_balance
#   • mucoid_sputum
#   • nodal_skin_eruptions
#   • obesity
#   • pain_behind_the_eyes
#   • palpitations
#   • polyuria
#   • rusty_sputum
#   • sinus_pressure
#   • slurred_speech
#   • stiff_neck
#   • throat_irritation
#   • ulcers_on_tongue
#   • unsteadiness
#   • watering_from_eyes
#   • weakness_of_one_body_side
#   • yellow_urine
#   • yellowing_of_eyes
#
# 🔵 Severity Level 3:
#   • acidity
#   • back_pain
#   • chills
#   • depression
#   • headache
#   • joint_pain
#   • knee_pain
#   • lack_of_concentration
#   • loss_of_smell
#   • mood_swings
#   • muscle_wasting
#   • red_spots_over_body
#   • skin_peeling
#   • skin_rash
#   • sunken_eyes
#   • sweating
#   • visual_disturbances
#   • weight_gain
#   • weight_loss
#   • yellow_crust_ooze
#   • yellowish_skin
#
# 🔵 Severity Level 2:
#   • altered_sensorium
#   • blackheads
#   • hip_joint_pain
#   • inflammatory_nails
#   • irritability
#   • lethargy
#   • muscle_pain
#   • muscle_weakness
#   • painful_walking
#   • pus_filled_pimples
#   • receiving_unsterile_injections
#   • red_sore_around_nose
#   • scurring
#   • silver_like_dusting
#   • small_dents_in_nails
#
# 🔵 Severity Level 1:
#   • itching
#
# 📋 Symptom Catalog:
# 1. View all symptoms
# 2. Search symptoms
# 3. View by category
# 4. Return to main menu
#
# 🔍 Matching Symptoms:
# 1. headache
# 2. blackheads
#
# 📋 Symptom Catalog:
# 1. View all symptoms
# 2. Search symptoms
# 3. View by category
# 4. Return to main menu
#
# 📋 Symptoms by Category:
#
# 🔵 Head & Neurological:
#   • blackheads
#   • headache
#
# 🔵 Respiratory:
#   • breathlessness
#   • chest_pain
#   • cough
#
# 🔵 Digestive:
#   • indigestion
#   • nausea
#   • pain_during_bowel_movements
#   • stomach_bleeding
#   • stomach_pain
#   • swelling_of_stomach
#
# 🔵 Musculoskeletal:
#   • abdominal_pain
#   • back_pain
#   • belly_pain
#   • hip_joint_pain
#   • joint_pain
#   • knee_pain
#   • muscle_pain
#   • muscle_wasting
#   • muscle_weakness
#   • neck_pain
#   • pain_behind_the_eyes
#   • pain_in_anal_region
#   • painful_walking
#   • swelling_joints
#
# 🔵 Skin:
#   • internal_itching
#   • itching
#   • nodal_skin_eruptions
#   • skin_peeling
#   • skin_rash
#   • yellowish_skin
#
# 🔵 General:
#   • abnormal_menstruation
#   • acidity
#   • acute_liver_failure
#   • altered_sensorium
#   • anxiety
#   • bladder_discomfort
#   • blister
#   • blood_in_sputum
#   • bloody_stool
#   • blurred_and_distorted_vision
#   • brittle_nails
#   • bruising
#   • burning_micturition
#   • chills
#   • cold_hands_and_feets
#   • coma
#   • congestion
#   • constipation
#   • continuous_feel_of_urine
#   • continuous_sneezing
#   • cramps
#   • dark_urine
#   • dehydration
#   • depression
#   • diarrhoea
#   • dischromic_patches
#   • distention_of_abdomen
#   • dizziness
#   • drying_and_tingling_lips
#   • enlarged_thyroid
#   • excessive_hunger
#   • extra_marital_contacts
#   • family_history
#   • fast_heart_rate
#   • fatigue
#   • fluid_overload
#   • foul_smell_ofurine
#   • high_fever
#   • history_of_alcohol_consumption
#   • increased_appetite
#   • inflammatory_nails
#   • irregular_sugar_level
#   • irritability
#   • irritation_in_anus
#   • lack_of_concentration
#   • lethargy
#   • loss_of_appetite
#   • loss_of_balance
#   • loss_of_smell
#   • malaise
#   • mild_fever
#   • mood_swings
#   • movement_stiffness
#   • mucoid_sputum
#   • obesity
#   • palpitations
#   • passage_of_gases
#   • patches_in_throat
#   • phlegm
#   • polyuria
#   • prognosis
#   • prominent_veins_on_calf
#   • puffy_face_and_eyes
#   • pus_filled_pimples
#   • receiving_blood_transfusion
#   • receiving_unsterile_injections
#   • red_sore_around_nose
#   • red_spots_over_body
#   • redness_of_eyes
#   • restlessness
#   • runny_nose
#   • rusty_sputum
#   • scurring
#   • shivering
#   • silver_like_dusting
#   • sinus_pressure
#   • slurred_speech
#   • small_dents_in_nails
#   • spinning_movements
#   • spotting_urination
#   • stiff_neck
#   • sunken_eyes
#   • sweating
#   • swelled_lymph_nodes
#   • swollen_blood_vessels
#   • swollen_extremeties
#   • swollen_legs
#   • throat_irritation
#   • toxic_look_(typhos)
#   • ulcers_on_tongue
#   • unsteadiness
#   • visual_disturbances
#   • vomiting
#   • watering_from_eyes
#   • weakness_in_limbs
#   • weakness_of_one_body_side
#   • weight_gain
#   • weight_loss
#   • yellow_crust_ooze
#   • yellow_urine
#   • yellowing_of_eyes
#
# 📋 Symptom Catalog:
# 1. View all symptoms
# 2. Search symptoms
# 3. View by category
# 4. Return to main menu
#
# ========================================
# 🏥 Medical Assistant - laasya's Session
# ========================================
#
# 📋 Menu Options:
# 1. Describe your symptoms
# 2. Browse symptom catalog
# 3. View your current symptoms
# 4. Emergency information
# 5. Help & Instructions
# 6. Exit
#
# 🚨 EMERGENCY INFORMATION 🚨
# ==================================================
#
# If you experience any of these symptoms:
# • Difficulty breathing or shortness of breath
# • Chest pain or pressure
# • Sudden severe pain
# • Sudden confusion or inability to speak
# • Severe allergic reaction
#
# ⚠️ IMMEDIATELY:
# 1. Call your local emergency number:
#    • United States: 911
#    • Europe: 112
#    • UK: 999
# 2. Do not wait - every minute counts!
# 3. If possible, have someone stay with you
#
# ========================================
# 🏥 Medical Assistant - laasya's Session
# ========================================
#
# 📋 Menu Options:
# 1. Describe your symptoms
# 2. Browse symptom catalog
# 3. View your current symptoms
# 4. Emergency information
# 5. Help & Instructions
# 6. Exit
#
# 📋 How to Use This System:
# 1. You can either describe your symptoms or choose from our list
# 2. The system will analyze your symptoms and suggest possible conditions
# 3. Follow-up questions will help refine the diagnosis
# 4. You can view detailed information about conditions
#
# ⚠️ Important: If you experience severe symptoms, seek immediate
#    medical attention or call emergency services.
#
# ========================================
# 🏥 Medical Assistant - laasya's Session
# ========================================
#
# 📋 Menu Options:
# 1. Describe your symptoms
# 2. Browse symptom catalog
# 3. View your current symptoms
# 4. Emergency information
# 5. Help & Instructions
# 6. Exit
#
# ============================================================
# 👋 Thank you for using our service, laasya!
# Take care and remember to consult healthcare professionals
# for proper medical advice and treatment.
# ============================================================
